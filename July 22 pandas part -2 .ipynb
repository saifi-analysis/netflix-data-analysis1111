# %%
import pandas as pd
customer = pd.read_csv("messy_customers.csv")
order_details = pd.read_csv("messy_order_items.csv")
orders= pd.read_csv("messy_orders.csv")
products= pd.read_csv("messy_products.csv",encoding = "latin1")


df = pd.DataFrame({
    "ID":[101,102,103,104,105,106,107,108,109,110],
    "order_item":["Monitor","Keyboard","Mouse","CPU","GPU","Motherboard","RAM","SSD","UPS","scanner"],
    "price":[1000,2000,3000,4000,5000,6000,7000,8000,9000,45600]
},
                  index=["amit","sumit","rohan","sohan","mohan","manish","priya","shreya","jay","mayank"])

# %%
order_details
# Out:
#       order_item_id order_id product_id  quantity  unit_price
# 0                 1   O00380       P033       2.0         NaN
# 1                 2   O00857       P010       1.0         NaN
# 2                 3   O00589       P007       2.0     77415.0
# 3                 4   O00112       P045       2.0     49066.0
# 4                 5   O00322       P036       2.0     58380.0
# ...             ...      ...        ...       ...         ...
# 2045           1166   O00667       P034       3.0     47907.0
# 2046            841   O00120       P050       4.0     41680.0
# 2047            399   O00053       P055       NaN         NaN
# 2048            545   O01182       P005       3.0         NaN
# 2049           1233   O00581       P047       1.0     89224.0
#
# [2050 rows x 5 columns]

# %%
order_details [order_details['unit_price'] > 50000]
# Out:
#       order_item_id order_id product_id  quantity  unit_price
# 2                 3   O00589       P007       2.0     77415.0
# 4                 5   O00322       P036       2.0     58380.0
# 7                 8   O00046       P062       2.0     87380.0
# 11               12   O01134       P076       3.0     74274.0
# 17               18   O00913       P065       1.0     55890.0
# ...             ...      ...        ...       ...         ...
# 2023            549   O00681       P002       3.0     63663.0
# 2027            197   O00301       P003       3.0     60818.0
# 2036           1814   O00575       P080       0.0     80491.0
# 2037            716   O00473       P040       3.0     55590.0
# 2049           1233   O00581       P047       1.0     89224.0
#
# [457 rows x 5 columns]

# %%
order_details [(order_details['unit_price'] > 50000) & (order_details['quantity']==2.0)]
# Out:
#       order_item_id order_id product_id  quantity  unit_price
# 2                 3   O00589       P007       2.0     77415.0
# 4                 5   O00322       P036       2.0     58380.0
# 7                 8   O00046       P062       2.0     87380.0
# 24               25   O00586       P010       2.0     60248.0
# 137             138   O00979       P074       2.0     85963.0
# ...             ...      ...        ...       ...         ...
# 1889           1890   O00021       P039       2.0     87975.0
# 1918           1919   O00871       P075       2.0     72184.0
# 2005           1420   O00327       P039       2.0     53326.0
# 2010           1532   O00015       P075       2.0     56095.0
# 2018           1372   O01191       P076       2.0     89156.0
#
# [67 rows x 5 columns]

# %%
order_details [(order_details['unit_price'] > 50000) | (order_details['quantity']==2.0)]
# Out:
#       order_item_id order_id product_id  quantity  unit_price
# 0                 1   O00380       P033       2.0         NaN
# 2                 3   O00589       P007       2.0     77415.0
# 3                 4   O00112       P045       2.0     49066.0
# 4                 5   O00322       P036       2.0     58380.0
# 7                 8   O00046       P062       2.0     87380.0
# ...             ...      ...        ...       ...         ...
# 2036           1814   O00575       P080       0.0     80491.0
# 2037            716   O00473       P040       3.0     55590.0
# 2043           1601   O00843       P078       2.0         NaN
# 2044            999   O00921       P073       2.0         NaN
# 2049           1233   O00581       P047       1.0     89224.0
#
# [712 rows x 5 columns]

# %% [raw]
# in python and condition is implemented by 'and'
# in pandas and condition is implemented by &
#
#
# in python or condition is implemented by 'or'
# in pandas or condition is implemented by |

# %%
order_details.query() # WE can use a syntax like MYSQL

# %%
# select * from order_details where quantity=0;
order_details.query("quantity==0")
# Out:
#       order_item_id order_id product_id  quantity  unit_price
# 6                 7   O00288       P070       0.0         NaN
# 20               21   O00594       P076       0.0     59441.0
# 26               27   O00912       P047       0.0         NaN
# 32               33   O00882       P014       0.0     25382.0
# 45               46   O01134       P017       0.0         NaN
# ...             ...      ...        ...       ...         ...
# 2020            306   O00354       P053       0.0         NaN
# 2034           1772   O00900       P058       0.0         NaN
# 2036           1814   O00575       P080       0.0     80491.0
# 2038           1805   O00977       P058       0.0         NaN
# 2040           1161   O01195       P020       0.0         NaN
#
# [341 rows x 5 columns]

# %%
# select * from order_details where quantity=0 and unit_price>=60000;
order_details.query("quantity==0 and unit_price>=60000")
# Out:
#       order_item_id order_id product_id  quantity  unit_price
# 115             116   O01012       P064       0.0     87243.0
# 132             133   O00996       P057       0.0     67021.0
# 209             210   O00155       P061       0.0     86125.0
# 212             213   O00615       P022       0.0     74631.0
# 213             214   O00412       P052       0.0     75650.0
# 236             237   O00442       P074       0.0     83343.0
# 253             254   O00053       P040       0.0     65419.0
# 258             259   O01095       P063       0.0     65624.0
# 265             266   O00398       P015       0.0     79531.0
# 273             274   O00384       P080       0.0     63653.0
# 312             313   O00029       P025       0.0     63996.0
# 353             354   O00185       P077       0.0     86726.0
# 378             379   O00324       P035       0.0     60638.0
# 379             380   O00996       P052       0.0     74550.0
# ...

# %%
n = 75000
q =0

order_details.query("quantity==@q and unit_price>@n")
# Out:
#       order_item_id order_id product_id  quantity  unit_price
# 115             116   O01012       P064       0.0     87243.0
# 209             210   O00155       P061       0.0     86125.0
# 213             214   O00412       P052       0.0     75650.0
# 236             237   O00442       P074       0.0     83343.0
# 265             266   O00398       P015       0.0     79531.0
# 353             354   O00185       P077       0.0     86726.0
# 410             411   O01054       P072       0.0     85189.0
# 629             630   O00650       P052       0.0     83661.0
# 815             816   O00675       P007       0.0     82381.0
# 825             826   O00136       P078       0.0     86702.0
# 874             875   O00165       P033       0.0     76814.0
# 898             899   O00038       P050       0.0     76969.0
# 951             952   O00838       P041       0.0     84151.0
# 1137           1138   O00523       P059       0.0     79384.0
# ...

# %%
order_details.query("100<order_item_id<200") # chained comparision
# Out:
#       order_item_id order_id product_id  quantity  unit_price
# 100             101   O01101       P080       0.0         NaN
# 101             102   O01002       P021       0.0     39349.0
# 102             103   O00871       P039       0.0         NaN
# 103             104   O00048       P057       NaN         NaN
# 104             105   O00953       P008       0.0         NaN
# ...             ...      ...        ...       ...         ...
# 198             199   O01065       P013       NaN     65979.0
# 2011            111   O01090       P018       0.0     41057.0
# 2015            159   O00727       P002       1.0     34931.0
# 2027            197   O00301       P003       3.0     60818.0
# 2039            156   O00621       P020       1.0         NaN
#
# [103 rows x 5 columns]

# %%
order_details [ order_details.isnull() ]
# Out:
#       order_item_id order_id product_id  quantity  unit_price
# 0               NaN      NaN        NaN       NaN         NaN
# 1               NaN      NaN        NaN       NaN         NaN
# 2               NaN      NaN        NaN       NaN         NaN
# 3               NaN      NaN        NaN       NaN         NaN
# 4               NaN      NaN        NaN       NaN         NaN
# ...             ...      ...        ...       ...         ...
# 2045            NaN      NaN        NaN       NaN         NaN
# 2046            NaN      NaN        NaN       NaN         NaN
# 2047            NaN      NaN        NaN       NaN         NaN
# 2048            NaN      NaN        NaN       NaN         NaN
# 2049            NaN      NaN        NaN       NaN         NaN
#
# [2050 rows x 5 columns]

# %%
order_details["quantity"].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2045    False
# 2046    False
# 2047     True
# 2048    False
# 2049    False
# Name: quantity, Length: 2050, dtype: bool

# %%
order_details[order_details["quantity"].isnull()]
# Out:
#       order_item_id order_id product_id  quantity  unit_price
# 12               13   O00147       P072       NaN         NaN
# 13               14   O00103       P040       NaN     27760.0
# 15               16   O00084       P066       NaN         NaN
# 18               19   O00648       P022       NaN         NaN
# 70               71   O00232       P078       NaN     74303.0
# ...             ...      ...        ...       ...         ...
# 2026            546   O00636       P010       NaN         NaN
# 2029            594   O00372       P057       NaN         NaN
# 2032            650   O00458       P040       NaN     17163.0
# 2042            997   O01103       P011       NaN     33021.0
# 2047            399   O00053       P055       NaN         NaN
#
# [318 rows x 5 columns]

# %%
# find all the null value inside a table
order_details.isnull().sum()
# Out:
# order_item_id       0
# order_id            0
# product_id          0
# quantity          318
# unit_price       1011
# dtype: int64

# %%
order_details.drop(columns=["unit_price"])
# Out:
#       order_item_id order_id product_id  quantity
# 0                 1   O00380       P033       2.0
# 1                 2   O00857       P010       1.0
# 2                 3   O00589       P007       2.0
# 3                 4   O00112       P045       2.0
# 4                 5   O00322       P036       2.0
# ...             ...      ...        ...       ...
# 2045           1166   O00667       P034       3.0
# 2046            841   O00120       P050       4.0
# 2047            399   O00053       P055       NaN
# 2048            545   O01182       P005       3.0
# 2049           1233   O00581       P047       1.0
#
# [2050 rows x 4 columns]

# %% [raw]
# order_details = order_details.drop(columns=["unit_price"])
# order_details.drop(columns=["unit_price"],inplace=True)

# %%
order_details
# Out:
#       order_item_id order_id product_id  quantity  unit_price
# 0                 1   O00380       P033       2.0         NaN
# 1                 2   O00857       P010       1.0         NaN
# 2                 3   O00589       P007       2.0     77415.0
# 3                 4   O00112       P045       2.0     49066.0
# 4                 5   O00322       P036       2.0     58380.0
# ...             ...      ...        ...       ...         ...
# 2045           1166   O00667       P034       3.0     47907.0
# 2046            841   O00120       P050       4.0     41680.0
# 2047            399   O00053       P055       NaN         NaN
# 2048            545   O01182       P005       3.0         NaN
# 2049           1233   O00581       P047       1.0     89224.0
#
# [2050 rows x 5 columns]

# %%
order_details.drop(columns=["unit_price"],inplace=True)

# %%
order_details
# Out:
#       order_item_id order_id product_id  quantity
# 0                 1   O00380       P033       2.0
# 1                 2   O00857       P010       1.0
# 2                 3   O00589       P007       2.0
# 3                 4   O00112       P045       2.0
# 4                 5   O00322       P036       2.0
# ...             ...      ...        ...       ...
# 2045           1166   O00667       P034       3.0
# 2046            841   O00120       P050       4.0
# 2047            399   O00053       P055       NaN
# 2048            545   O01182       P005       3.0
# 2049           1233   O00581       P047       1.0
#
# [2050 rows x 4 columns]

# %%
order_details
# Out:
#       order_item_id order_id product_id  quantity  unit_price
# 0                 1   O00380       P033       2.0         NaN
# 1                 2   O00857       P010       1.0         NaN
# 2                 3   O00589       P007       2.0     77415.0
# 3                 4   O00112       P045       2.0     49066.0
# 4                 5   O00322       P036       2.0     58380.0
# ...             ...      ...        ...       ...         ...
# 2045           1166   O00667       P034       3.0     47907.0
# 2046            841   O00120       P050       4.0     41680.0
# 2047            399   O00053       P055       NaN         NaN
# 2048            545   O01182       P005       3.0         NaN
# 2049           1233   O00581       P047       1.0     89224.0
#
# [2050 rows x 5 columns]

# %%
order_details.drop(labels=[2049])
# Out:
#       order_item_id order_id product_id  quantity  unit_price
# 0                 1   O00380       P033       2.0         NaN
# 1                 2   O00857       P010       1.0         NaN
# 2                 3   O00589       P007       2.0     77415.0
# 3                 4   O00112       P045       2.0     49066.0
# 4                 5   O00322       P036       2.0     58380.0
# ...             ...      ...        ...       ...         ...
# 2044            999   O00921       P073       2.0         NaN
# 2045           1166   O00667       P034       3.0     47907.0
# 2046            841   O00120       P050       4.0     41680.0
# 2047            399   O00053       P055       NaN         NaN
# 2048            545   O01182       P005       3.0         NaN
#
# [2049 rows x 5 columns]

# %%
order_details.dropna()
# Out:
#       order_item_id order_id product_id  quantity  unit_price
# 2                 3   O00589       P007       2.0     77415.0
# 3                 4   O00112       P045       2.0     49066.0
# 4                 5   O00322       P036       2.0     58380.0
# 7                 8   O00046       P062       2.0     87380.0
# 10               11   O00609       P006       3.0     12037.0
# ...             ...      ...        ...       ...         ...
# 2036           1814   O00575       P080       0.0     80491.0
# 2037            716   O00473       P040       3.0     55590.0
# 2045           1166   O00667       P034       3.0     47907.0
# 2046            841   O00120       P050       4.0     41680.0
# 2049           1233   O00581       P047       1.0     89224.0
#
# [872 rows x 5 columns]

# %%
order_details['quantity'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 order_details['quantity'].astype(int)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537     results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6539 else:
#    6540     # else, only a single dtype is given
# -> 6541     new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\internals\managers.py:614, in BaseBlockManager.astype(self, dtype, errors)
#     613 def astype(self, dtype, errors: str = "raise") -> Self:
# ...

# %%
order_details.fillna("a")
# Out:
#       order_item_id order_id product_id quantity unit_price
# 0                 1   O00380       P033      2.0          a
# 1                 2   O00857       P010      1.0          a
# 2                 3   O00589       P007      2.0    77415.0
# 3                 4   O00112       P045      2.0    49066.0
# 4                 5   O00322       P036      2.0    58380.0
# ...             ...      ...        ...      ...        ...
# 2045           1166   O00667       P034      3.0    47907.0
# 2046            841   O00120       P050      4.0    41680.0
# 2047            399   O00053       P055        a          a
# 2048            545   O01182       P005      3.0          a
# 2049           1233   O00581       P047      1.0    89224.0
#
# [2050 rows x 5 columns]

# %%
order_details['quantity'].sum()
# Out:
# np.float64(3449.0)

# %%
order_details['quantity'].mean() # 1
# Out:
# np.float64(1.9913394919168592)

# %%
order_details['quantity'].median() # 2
# Out:
# np.float64(2.0)

# %%
order_details['quantity'].min()
# Out:
# np.float64(0.0)

# %%
order_details['quantity'].max()
# Out:
# np.float64(4.0)

# %%
round(order_details['quantity'].mean(),0)
# Out:
# np.float64(2.0)

# %%
order_details['quantity'].fillna(round(order_details['quantity'].mean(),0),inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9092\937280621.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   order_details['quantity'].fillna(round(order_details['quantity'].mean(),0),inplace=True)
# 0       2.0
# 1       1.0
# 2       2.0
# 3       2.0
# 4       2.0
#        ...
# 2045    3.0
# 2046    4.0
# ...

# %%
order_details.fillna({'quantity':round(order_details['quantity'].mean(),0)},inplace=True)
# Out:
#       order_item_id order_id product_id  quantity  unit_price
# 0                 1   O00380       P033       2.0         NaN
# 1                 2   O00857       P010       1.0         NaN
# 2                 3   O00589       P007       2.0     77415.0
# 3                 4   O00112       P045       2.0     49066.0
# 4                 5   O00322       P036       2.0     58380.0
# ...             ...      ...        ...       ...         ...
# 2045           1166   O00667       P034       3.0     47907.0
# 2046            841   O00120       P050       4.0     41680.0
# 2047            399   O00053       P055       2.0         NaN
# 2048            545   O01182       P005       3.0         NaN
# 2049           1233   O00581       P047       1.0     89224.0
#
# [2050 rows x 5 columns]

# %%
order_details
# Out:
#       order_item_id order_id product_id  quantity  unit_price
# 0                 1   O00380       P033       2.0         NaN
# 1                 2   O00857       P010       1.0         NaN
# 2                 3   O00589       P007       2.0     77415.0
# 3                 4   O00112       P045       2.0     49066.0
# 4                 5   O00322       P036       2.0     58380.0
# ...             ...      ...        ...       ...         ...
# 2045           1166   O00667       P034       3.0     47907.0
# 2046            841   O00120       P050       4.0     41680.0
# 2047            399   O00053       P055       2.0         NaN
# 2048            545   O01182       P005       3.0         NaN
# 2049           1233   O00581       P047       1.0     89224.0
#
# [2050 rows x 5 columns]

# %%
order_details['quantity'] = order_details['quantity'].astype(int)

# %%
order_details
# Out:
#       order_item_id order_id product_id  quantity  unit_price
# 0                 1   O00380       P033         2         NaN
# 1                 2   O00857       P010         1         NaN
# 2                 3   O00589       P007         2     77415.0
# 3                 4   O00112       P045         2     49066.0
# 4                 5   O00322       P036         2     58380.0
# ...             ...      ...        ...       ...         ...
# 2045           1166   O00667       P034         3     47907.0
# 2046            841   O00120       P050         4     41680.0
# 2047            399   O00053       P055         2         NaN
# 2048            545   O01182       P005         3         NaN
# 2049           1233   O00581       P047         1     89224.0
#
# [2050 rows x 5 columns]

# %%
order_details [order_details['quantity'] == 0]
# Out:
#       order_item_id order_id product_id  quantity  unit_price
# 6                 7   O00288       P070         0         NaN
# 20               21   O00594       P076         0     59441.0
# 26               27   O00912       P047         0         NaN
# 32               33   O00882       P014         0     25382.0
# 45               46   O01134       P017         0         NaN
# ...             ...      ...        ...       ...         ...
# 2020            306   O00354       P053         0         NaN
# 2034           1772   O00900       P058         0         NaN
# 2036           1814   O00575       P080         0     80491.0
# 2038           1805   O00977       P058         0         NaN
# 2040           1161   O01195       P020         0         NaN
#
# [341 rows x 5 columns]

# %%
order_details['quantity'].replace({0:1})
# Out:
# 0       2
# 1       1
# 2       2
# 3       2
# 4       2
#        ..
# 2045    3
# 2046    4
# 2047    2
# 2048    3
# 2049    1
# Name: quantity, Length: 2050, dtype: int64

# %%
order_details['quantity'] = order_details['quantity'].replace({0:1})

# %%
order_details[order_details['quantity']==0]
# Out:
# Empty DataFrame
# Columns: [order_item_id, order_id, product_id, quantity, unit_price]
# Index: []

# %%
order_details['quantity'].value_counts()
# Out:
# quantity
# 1    711
# 2    640
# 3    361
# 4    338
# Name: count, dtype: int64

# %%
products
# Out:
#    product_id    product_name     category  base_price
# 0        P001  Lenovo IdeaPad       Tablet     28151.0
# 1        P002     Samsung Tab   Smartphone     68660.0
# 2        P003     HP Pavilion  Accessories         NaN
# 3        P004      Lenovo Tab       tablet         NaN
# 4        P005         OnePlus       Tablet         NaN
# ..        ...             ...          ...         ...
# 85       P022     Samsung Tab    Accessory         NaN
# 86       P052    Xiaomi Redmi  smart phone         NaN
# 87       P010       iPhone 13  smart phone         NaN
# 88       P059         OnePlus  Accessories         NaN
# 89       P033  Wireless Mouse       laptop     47453.0
#
# [90 rows x 4 columns]

# %%
products.isnull().sum()
# Out:
# product_id       0
# product_name     0
# category         0
# base_price      57
# dtype: int64

# %%
print(products.to_string())
# Out:
#    product_id    product_name     category  base_price
# 0        P001  Lenovo IdeaPad       Tablet     28151.0
# 1        P002     Samsung Tab   Smartphone     68660.0
# 2        P003     HP Pavilion  Accessories         NaN
# 3        P004      Lenovo Tab       tablet         NaN
# 4        P005         OnePlus       Tablet         NaN
# 5        P006      Laptop Bag       tablet         NaN
# 6        P007     HP Pavilion  Accessories         NaN
# 7        P008     HP Pavilion    Accessory         NaN
# 8        P009       iPhone 13       Tablet     70582.0
# 9        P010       iPhone 13  smart phone         NaN
# 10       P011  Lenovo IdeaPad  Accessories         NaN
# 11       P012  Lenovo IdeaPad    Accessory     27157.0
# 12       P013  Samsung Galaxy  smart phone     51735.0
# 13       P014    Xiaomi Redmi       Laptop      5475.0
# 14       P015      Laptop Bag  smart phone     76755.0
# 15       P016        iPad Air  smart phone         NaN
# ...

# %%
products["category"].value_counts()
# Out:
# category
# smart phone    17
# Tablet         16
# laptop         13
# Accessory      12
# Smartphone     11
# Accessories    11
# tablet          5
# Laptop          5
# Name: count, dtype: int64

# %%
products["category"] = products["category"].str.capitalize()

# %%
products["category"].value_counts()
# Out:
# category
# Tablet         21
# Laptop         18
# Smart phone    17
# Accessory      12
# Smartphone     11
# Accessories    11
# Name: count, dtype: int64

# %%
products["category"].replace({"Accessory":"Accessories" ,"Smart phone" : "Smartphone" })
# Out:
# 0          Tablet
# 1      Smartphone
# 2     Accessories
# 3          Tablet
# 4          Tablet
#          ...
# 85    Accessories
# 86     Smartphone
# 87     Smartphone
# 88    Accessories
# 89         Laptop
# Name: category, Length: 90, dtype: str

# %%
products["category"] = products["category"].replace({"Accessory":"Accessories" ,"Smart phone" : "Smartphone" })

# %%
products["category"].value_counts()
# Out:
# category
# Smartphone     28
# Accessories    23
# Tablet         21
# Laptop         18
# Name: count, dtype: int64
